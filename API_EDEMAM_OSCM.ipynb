# %% [markdown]
# # **Procedimiento para realizar consultas (request) a la base de datos de la API de EDEMAM**
# ## **Estudiante: Samuel Cortez / Maestría en Ciencia de Datos**

# %%
import pandas as pd
import requests
import json         
import logging

# %%
# Se define clase Edemam_mcd
class Edamam_mcd:
    "API que regresa datos de tipo json"
    def __init__(self, 
                id_nutrition, 
                key_nutrition, 
                id_recipes,
                key_recipes,
                id_food,
                key_food):
        
        # Asignación de claves / ID de las API's
        self.id_nut = id_nutrition
        self.key_nut = key_nutrition
        self.id_rec = id_recipes
        self.key_rec = key_recipes
        self.id_food = id_food
        self.key_food = key_food
    
    def Nut_Analysis(self, query):
        self.Nut_ingredients = query
        # Se define url para realizar consulta a la API Nutrition Analysis
        url_req_nutr = 'https://api.edamam.com/api/nutrition-data?app_id={id}&app_key={key}'.format(id=self.id_nut,key= self.key_nut)+'&nutrition-type=cooking&ingr='+self.Nut_ingredients
        # Envío de solicitud para realizar consulta de análisis nutricional
        Response = requests.get(url_req_nutr)

        # Imprimir el código del estatus
        print("Status Code (Nutrition Analysis API):", Response.status_code)
        
        if Response.status_code == 401:
            logging.error('{key} - Clave inválida (Nutrition Analysis API)'.format(key=self.key_nut))
        # Convertir como Json
        self.r_Nut = Response.json()
        return self.r_Nut

    def Search_recipe(self, query):
        self.query_recipe = query
        # Se define url para realizar consulta para busqueda de recetas de un platillo
        url_recipe = 'https://api.edamam.com/search?q={query}&app_id={id}&app_key={key}'.format(id=self.id_rec, key=self.key_rec,query=self.query_recipe)    
        Response = requests.get(url_recipe)

        # Imprimir el código de estatus
        print("Status Code (Recipe Search API) :", Response.status_code)
        
        if Response.status_code == 401:
            logging.error('{key} - Clave inválida (Recipe Search API)'.format(key=self.key_rec))
        # Convertir a Json
        self.r_Recipe = Response.json()

        return self.r_Recipe

    def Search_food(self, query):
        self.query_food = query
        # Se define url para realizar consulta de análisis de comida
        url_food = 'https://api.edamam.com/api/food-database/parser?nutrition-type=logging&ingr={query}&app_id={id}&app_key={key}' \
            .format(id=self.id_food, key=self.key_food, query=self.query_food)
        # Se realiza una consulta dando la url
        Response = requests.get(url_food)
        
        # Imprimir el código de estatus
        print("Status Code (Food Database API):", Response.status_code)

        if Response.status_code == 401:
            logging.error('{key} - Clave inválida (Food Database API)'.format(key=self.key_rec))

        # Convertir a json
        self.r_Food = Response.json()
        return self.r_Food
    
    # Conjunto de funciones para generar dataframes con los datos principales de las consultas

    def Nutrient_Guide(self):
        # Manejo de excepciones
        try:
            # Se crean DataFrames de las variables totalNutrients, totalDaily y totalNutrientsKCal 
            self.df_Nutrition= pd.DataFrame(self.r_Nut.get('totalNutrients')).T.rename_axis(str(self.Nut_ingredients))
            self.df_totalDaily = pd.DataFrame(self.r_Nut.get('totalDaily')).T.rename_axis(str(self.Nut_ingredients))
            self.df_total_Nut =  pd.DataFrame(Response_Nut.get('totalNutrientsKCal')).T.rename_axis(str(self.Nut_ingredients))
            # Se obtiene las calorías del alimento
            self.Nutrient_Cal = self.r_Nut.get('calories')
            # Se obtiene el peso total del alimento
            self.totalWeight = self.r_Nut.get('totalWeight')
        except Exception as e:
            print(e)
        
        
    def ingredients_table(self):
        # Manejo de excepciones
        try:
            # Comprensión de listas: se crean nuevas listas con las etiquetas de la receta y con los ingredientes
            list_label = [element_hits.get('recipe').get('label') for element_hits in Response_Recipe.get('hits')]
            list_ingredientes = [element_ingre.get('recipe').get('ingredients') for element_ingre in Response_Recipe.get('hits')]
            # Se construye DataFrame 
            df_ = pd.DataFrame(list_ingredientes, index=list_label).stack().apply(pd.Series).drop(columns=['foodId'])
            self.df_Recipe = df_.rename_axis(["Types", "Items"], axis = "rows").rename(columns = {"foodCategory": "food category", "text":"ingredient name"})
            
            return self.df_Recipe
        except Exception as e:
            print(e)

    def food_table(self):
        # Se generar listas vacias
        list_foods = []
        list_nutrients = []
        rename_nutrients = ['ENERGY (kcal)', 'PROTEIN (g)', 'FAT (g)', 'CARBS (g)', 'FIBER (g)']
        # Manejo de excepciones
        try:
            # Comprensión de listas: se crean nuevas listas con las etiquetas de los alimentos y con los nutrientes  
            list_foods = [element.get('food').get('label') for  element in self.r_Food['hints']]
            list_nutrients = [element.get('food').get('nutrients') for element in self.r_Food['hints']]
            # Se construye DataFrame
            self.df_food_table = pd.DataFrame(list_nutrients, index = list_foods).round(2).fillna('Unknown')
            self.df_food_table.columns = rename_nutrients
            return self.df_food_table
            
        except Exception as e:
            print(e) 
    
    def write_files(self):
        #  Exportar archivos .CSV/.xlsx
        path_Nutrition = '{Nut}_Nutritional_Analysis.xlsx'.format(Nut=self.Nut_ingredients)
        path_Recipe = '{Recipe}_Recipe.csv'.format(Recipe = self.query_recipe)
        path_food = '{food}_food.csv'.format(food = self.query_food)

        # Se exporta a excel el análisis nutricional 
        with pd.ExcelWriter(path_Nutrition) as writer:
            self.df_Nutrition.to_excel(writer, sheet_name= 'Nutritional_Analysis')
            self.df_totalDaily.to_excel(writer, sheet_name='Total_Daily')
            self.df_total_Nut.to_excel(writer, sheet_name='totalNutrientsKCal')
        # Se exporta en formato CSV los ingredientes de las recetas
        self.df_Recipe.to_csv(path_Recipe)
        # Se exporta en CSV el dataframe con el análisis de los alimentos
        self.df_food_table.to_csv(path_food)

# %%
# Claves / ID's de las aplicaciones asignadas
nutrition_appid= '5f1e7888'
nutrition_appkey= '5576413f5acb38f5259a58dad888d1b9'
recipes_appid = 'dcda2d5e'
recipes_appkey= '87ae2d34cdde47026fc341c8fbd7957f'
food_appid= '6b69c52c'
food_appkey= 'd5a448b534a0c358dfb47fa7a6548724'

# Se crea el objeto 
EDEMAM_consulta = Edamam_mcd(id_nutrition=nutrition_appid, 
                            key_nutrition= nutrition_appkey,
                            id_recipes=recipes_appid,
                            key_recipes=recipes_appkey,
                            id_food=food_appid,
                            key_food=food_appkey)

# Ejercución de los métodos de cada una de las API's para realizar consultas
Response_Nut = EDEMAM_consulta.Nut_Analysis(query= '2 hams')
Response_Food = EDEMAM_consulta.Search_food(query= 'coffe and pizza')
Response_Recipe = EDEMAM_consulta.Search_recipe(query= 'Twinkies')
# Ejecución de los métodos para obtener los dataframe con los resultados para cada una de las API's
EDEMAM_consulta.Nutrient_Guide()
EDEMAM_consulta.ingredients_table()
EDEMAM_consulta.food_table()
# Se exportan en archivos csv y xlsx los resultados obtenidos
EDEMAM_consulta.write_files()
# Out:
# Status Code (Nutrition Analysis API): 200
# Status Code (Food Database API): 200
# Status Code (Recipe Search API) : 200

# %%
# Consulta a la API: Nutrition Analysis obtenida en formato json
Response_Nut
# Out:
# {'uri': 'http://www.edamam.com/ontologies/edamam.owl#recipe_95620f46a47a4a7996864aecec9ac91c',
#  'calories': 29354,
#  'totalWeight': 16308.0,
#  'dietLabels': ['LOW_CARB'],
#  'healthLabels': ['SUGAR_CONSCIOUS',
#   'LOW_SUGAR',
#   'PALEO',
#   'DAIRY_FREE',
#   'GLUTEN_FREE',
#   'WHEAT_FREE',
#   'EGG_FREE',
#   'MILK_FREE',
#   'PEANUT_FREE',
#   'TREE_NUT_FREE',
#   'SOY_FREE',
#   'FISH_FREE',
#   'SHELLFISH_FREE',
#   'CRUSTACEAN_FREE',
#   'CELERY_FREE',
#   'MUSTARD_FREE',
#   'SESAME_FREE',
#   'LUPINE_FREE',
#   'MOLLUSK_FREE',
#   'ALCOHOL_FREE',
#   'NO_OIL_ADDED',
#   'NO_SUGAR_ADDED',
#   'SULPHITE_FREE'],
#  'cautions': ['SULFITES'],
#  'totalNutrients': {'ENERC_KCAL': {'label': 'Energy',
#    'quantity': 29354.4,
#    'unit': 'kcal'},
#   'FAT': {'label': 'Fat', 'quantity': 1679.7240000000002, 'unit': 'g'},
#   'FASAT': {'label': 'Saturated', 'quantity': 558.0597600000001, 'unit': 'g'},
#   'FAMS': {'label': 'Monounsaturated',
#    'quantity': 798.6027600000001,
#    'unit': 'g'},
#   'FAPU': {'label': 'Polyunsaturated',
#    'quantity': 205.48080000000002,
#    'unit': 'g'},
#   'CHOCDF': {'label': 'Carbs', 'quantity': 684.936, 'unit': 'g'},
#   'FIBTG': {'label': 'Fiber', 'quantity': 0.0, 'unit': 'g'},
#   'SUGAR': {'label': 'Sugars', 'quantity': 0.0, 'unit': 'g'},
#   'PROCNT': {'label': 'Protein', 'quantity': 2690.82, 'unit': 'g'},
#   'CHOLE': {'label': 'Cholesterol',
#    'quantity': 9621.720000000001,
#    'unit': 'mg'},
#   'NA': {'label': 'Sodium', 'quantity': 169440.12000000002, 'unit': 'mg'},
#   'CA': {'label': 'Calcium', 'quantity': 1141.5600000000002, 'unit': 'mg'},
#   'MG': {'label': 'Magnesium', 'quantity': 2609.28, 'unit': 'mg'},
#   'K': {'label': 'Potassium', 'quantity': 52022.520000000004, 'unit': 'mg'},
#   'FE': {'label': 'Iron', 'quantity': 135.3564, 'unit': 'mg'},
#   'ZN': {'label': 'Zinc', 'quantity': 316.3752, 'unit': 'mg'},
#   'P': {'label': 'Phosphorus', 'quantity': 25277.4, 'unit': 'mg'},
#   'VITA_RAE': {'label': 'Vitamin A', 'quantity': 0.0, 'unit': 'µg'},
#   'VITC': {'label': 'Vitamin C', 'quantity': 0.0, 'unit': 'mg'},
#   'THIA': {'label': 'Thiamin (B1)',
#    'quantity': 103.06656000000001,
#    'unit': 'mg'},
#   'RIBF': {'label': 'Riboflavin (B2)', 'quantity': 33.26832, 'unit': 'mg'},
#   'NIA': {'label': 'Niacin (B3)', 'quantity': 632.7504, 'unit': 'mg'},
#   'VITB6A': {'label': 'Vitamin B6', 'quantity': 57.078, 'unit': 'mg'},
#   'FOLDFE': {'label': 'Folate equivalent (total)',
#    'quantity': 163.08,
#    'unit': 'µg'},
#   'FOLFD': {'label': 'Folate (food)', 'quantity': 163.08, 'unit': 'µg'},
#   'FOLAC': {'label': 'Folic acid', 'quantity': 0.0, 'unit': 'µg'},
#   'VITB12': {'label': 'Vitamin B12', 'quantity': 150.0336, 'unit': 'µg'},
#   'VITD': {'label': 'Vitamin D', 'quantity': 114.156, 'unit': 'µg'},
#   'TOCPHA': {'label': 'Vitamin E', 'quantity': 37.5084, 'unit': 'mg'},
#   'VITK1': {'label': 'Vitamin K', 'quantity': 0.0, 'unit': 'µg'},
#   'WATER': {'label': 'Water', 'quantity': 10649.124, 'unit': 'g'}},
#  'totalDaily': {'ENERC_KCAL': {'label': 'Energy',
#    'quantity': 1467.72,
#    'unit': '%'},
#   'FAT': {'label': 'Fat', 'quantity': 2584.1907692307695, 'unit': '%'},
#   'FASAT': {'label': 'Saturated', 'quantity': 2790.2988000000005, 'unit': '%'},
#   'CHOCDF': {'label': 'Carbs', 'quantity': 228.312, 'unit': '%'},
#   'FIBTG': {'label': 'Fiber', 'quantity': 0.0, 'unit': '%'},
#   'PROCNT': {'label': 'Protein', 'quantity': 5381.64, 'unit': '%'},
#   'CHOLE': {'label': 'Cholesterol',
#    'quantity': 3207.2400000000002,
#    'unit': '%'},
#   'NA': {'label': 'Sodium', 'quantity': 7060.005000000002, 'unit': '%'},
#   'CA': {'label': 'Calcium', 'quantity': 114.15600000000002, 'unit': '%'},
#   'MG': {'label': 'Magnesium', 'quantity': 621.257142857143, 'unit': '%'},
#   'K': {'label': 'Potassium', 'quantity': 1106.8621276595745, 'unit': '%'},
#   'FE': {'label': 'Iron', 'quantity': 751.98, 'unit': '%'},
#   'ZN': {'label': 'Zinc', 'quantity': 2876.1381818181817, 'unit': '%'},
#   'P': {'label': 'Phosphorus', 'quantity': 3611.057142857143, 'unit': '%'},
#   'VITA_RAE': {'label': 'Vitamin A', 'quantity': 0.0, 'unit': '%'},
#   'VITC': {'label': 'Vitamin C', 'quantity': 0.0, 'unit': '%'},
#   'THIA': {'label': 'Thiamin (B1)',
#    'quantity': 8588.880000000001,
#    'unit': '%'},
#   'RIBF': {'label': 'Riboflavin (B2)',
#    'quantity': 2559.1015384615384,
#    'unit': '%'},
#   'NIA': {'label': 'Niacin (B3)', 'quantity': 3954.69, 'unit': '%'},
#   'VITB6A': {'label': 'Vitamin B6',
#    'quantity': 4390.615384615385,
#    'unit': '%'},
#   'FOLDFE': {'label': 'Folate equivalent (total)',
#    'quantity': 40.77,
#    'unit': '%'},
#   'VITB12': {'label': 'Vitamin B12',
#    'quantity': 6251.400000000001,
#    'unit': '%'},
#   'VITD': {'label': 'Vitamin D', 'quantity': 761.0400000000001, 'unit': '%'},
#   'TOCPHA': {'label': 'Vitamin E', 'quantity': 250.056, 'unit': '%'},
#   'VITK1': {'label': 'Vitamin K', 'quantity': 0.0, 'unit': '%'}},
#  'totalNutrientsKCal': {'ENERC_KCAL': {'label': 'Energy',
#    'quantity': 29354,
#    'unit': 'kcal'},
#   'PROCNT_KCAL': {'label': 'Calories from protein',
#    'quantity': 11039,
#    'unit': 'kcal'},
#   'FAT_KCAL': {'label': 'Calories from fat',
#    'quantity': 15505,
#    'unit': 'kcal'},
#   'CHOCDF_KCAL': {'label': 'Calories from carbohydrates',
#    'quantity': 2810,
#    'unit': 'kcal'}}}

# %%
# Consulta a la API: Food Database obtenida en formato json
Response_Food
# Out:
# {'text': 'coffe and pizza',
#  'parsed': [{'food': {'foodId': 'food_at830s9amds32fb8w6ufmaopzk8n',
#     'label': 'Pizza',
#     'nutrients': {'ENERC_KCAL': 268.0,
#      'PROCNT': 10.36,
#      'FAT': 12.28,
#      'CHOCDF': 29.02,
#      'FIBTG': 2.2},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
#     'image': 'https://www.edamam.com/food-img/c01/c0150280d71059c23c025f501f502dc0.jpg'},
#    'quantity': 1.0,
#    'measure': {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#     'label': 'Serving'}}],
#  'hints': [{'food': {'foodId': 'food_at830s9amds32fb8w6ufmaopzk8n',
#     'label': 'Pizza',
#     'nutrients': {'ENERC_KCAL': 268.0,
#      'PROCNT': 10.36,
#      'FAT': 12.28,
#      'CHOCDF': 29.02,
#      'FIBTG': 2.2},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
#     'image': 'https://www.edamam.com/food-img/c01/c0150280d71059c23c025f501f502dc0.jpg'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pizza',
#      'label': 'Pizza'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_package',
#      'label': 'Package'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_b3wf7mubtbjih5b42m445bpwqofu',
#     'label': 'Coffe, Large',
#     'nutrients': {'ENERC_KCAL': 0.845350567546075,
#      'PROCNT': 0.169070113509215,
#      'FAT': 0.0,
#      'CHOCDF': 0.0,
#      'FIBTG': 0.0},
#     'brand': 'White Castle',
#     'category': 'Fast foods',
#     'categoryLabel': 'meal'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_fluid_ounce',
#      'label': 'Fluid ounce'}]},
#   {'food': {'foodId': 'food_an3m60hbl0a1iibqmmr1paxost5f',
#     'label': 'Coffe, Medium',
#     'nutrients': {'ENERC_KCAL': 1.0566882094325938,
#      'PROCNT': 0.21133764188651874,
#      'FAT': 0.0,
#      'CHOCDF': 0.0,
#      'FIBTG': 0.0},
#     'brand': 'White Castle',
#     'category': 'Fast foods',
#     'categoryLabel': 'meal'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_fluid_ounce',
#      'label': 'Fluid ounce'}]},
#   {'food': {'foodId': 'food_b20nj78ajzve2qbjgnu8qbsazgdb',
#     'label': 'Sausage Pizza',
#     'nutrients': {'ENERC_KCAL': 280.0,
#      'PROCNT': 11.5,
#      'FAT': 12.35,
#      'CHOCDF': 30.62,
#      'FIBTG': 2.3},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
#     'image': 'https://www.edamam.com/food-img/7e4/7e4559e8b0dea671e0d0e7cd2fecbef5.jpg'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pizza',
#      'label': 'Pizza'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_slice',
#      'label': 'Slice'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_aeqk7lua3h3qopbk2qew0aeif5p8',
#     'label': 'Pepperoni Pizza',
#     'nutrients': {'ENERC_KCAL': 282.0,
#      'PROCNT': 11.74,
#      'FAT': 11.91,
#      'CHOCDF': 31.98,
#      'FIBTG': 2.3},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
#     'image': 'https://www.edamam.com/food-img/a85/a85bb70cafe70e500090f722f261bb9a.jpg'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pizza',
#      'label': 'Pizza'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_slice',
#      'label': 'Slice'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_bpvljzfb2jzuzfaqjwwirbqmehbr',
#     'label': 'Stuffed Cheeze Pizza',
#     'nutrients': {'ENERC_KCAL': 274.0,
#      'PROCNT': 12.23,
#      'FAT': 11.63,
#      'CHOCDF': 30.0,
#      'FIBTG': 1.7},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
#     'image': 'https://www.edamam.com/food-img/f3f/f3fd1d8fc397d147c565d2a3f438055b.jpg'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole',
#      'qualified': [[{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Qualifier_whole',
#         'label': 'whole'}]]},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pizza',
#      'label': 'Pizza',
#      'qualified': [[{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Qualifier_whole',
#         'label': 'whole'}]]},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_slice',
#      'label': 'Slice'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_aruq9sya47lfibb4fkrrnalah1r0',
#     'label': 'Veggy Cheese Pizza',
#     'nutrients': {'ENERC_KCAL': 244.0,
#      'PROCNT': 11.02,
#      'FAT': 10.9,
#      'CHOCDF': 25.38,
#      'FIBTG': 2.2},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
#     'image': 'https://www.edamam.com/food-img/f8e/f8ece99f2bccc4261c4e45fa3305e029.jpg'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pie',
#      'label': 'Pie'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_slice',
#      'label': 'Slice'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_b6ozc3aarrswiba2woiqxbztcmxc',
#     'label': 'Nestle Coffee Mate Coffe Creamer Hazelnut',
#     'nutrients': {'ENERC_KCAL': 236.69815891690286,
#      'PROCNT': 0.0,
#      'FAT': 6.762804540482938,
#      'CHOCDF': 33.81402270241469},
#     'brand': 'Nestle',
#     'category': 'Packaged foods',
#     'categoryLabel': 'food',
#     'foodContentsLabel': 'WATER; SUGAR; PARTIALLY HYDROGENATED SOYBEAN AND/OR COTTONSEED OIL; AND LESS THAN 2% OF SODIUM CASEINATE (A MILK DERIVATIVE)**; DIPOTASSIUM PHOSPHATE; DISODIUM PHOSPHATE; MONO-AND DIGLYCERIDES; CELLULOSE GEL; CELLULOSE GUM; COLOR ADDED; NATURAL AND ARTIFICIAL FLAVORS; CARRAGEENAN. **NOT A SOURCE OF LACTOSE',
#     'image': 'https://www.edamam.com/food-img/388/3888b854262fd0f97c4f473a72d952fc.png'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_package',
#      'label': 'Package'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_tablespoon',
#      'label': 'Tablespoon'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_milliliter',
#      'label': 'Milliliter'}]},
#   {'food': {'foodId': 'food_anpwlglb1l57uvaulryh6bax4hhl',
#     'label': 'Nestle Coffee Mate Coffe Creamer Hazelnut',
#     'nutrients': {'ENERC_KCAL': 236.69815891690286,
#      'PROCNT': 0.0,
#      'FAT': 6.762804540482938,
#      'CHOCDF': 33.81402270241469},
#     'brand': 'Nestle',
#     'category': 'Packaged foods',
#     'categoryLabel': 'food',
#     'foodContentsLabel': 'WATER; SUGAR; PARTIALLY HYDROGENATED SOYBEAN AND/OR COTTONSEED OIL; AND LESS THAN 2% OF SODIUM CASEINATE (A MILK DERIVATIVE)**; DIPOTASSIUM PHOSPHATE; DISODIUM PHOSPHATE; MONO- AND DIGLYCERIDES; CELLULOSE GEL; CELLULOSE GUM; COLOR ADDED; NATURAL AND ARTIFICIAL FLAVORS; CARRAGEENAN. **NOT A SOURCE OF LACTOSE.',
#     'image': 'https://www.edamam.com/food-img/388/3888b854262fd0f97c4f473a72d952fc.png'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_package',
#      'label': 'Package'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_tablespoon',
#      'label': 'Tablespoon'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_milliliter',
#      'label': 'Milliliter'}]},
#   {'food': {'foodId': 'food_a9vhvy4ahiebfhakua8bbba32cpn',
#     'label': 'Thick Crust Sausage Pizza',
#     'nutrients': {'ENERC_KCAL': 282.0,
#      'PROCNT': 11.06,
#      'FAT': 12.94,
#      'CHOCDF': 30.36,
#      'FIBTG': 2.3},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
#     'image': 'https://www.edamam.com/food-img/544/54416c720c37c11e458db8a9d1487fbb.jpg'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pizza',
#      'label': 'Pizza'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_slice',
#      'label': 'Slice'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_ajfl92ta7r7byxa0rljv5bx3u6ir',
#     'label': 'Thin Crust Cheese Pizza',
#     'nutrients': {'ENERC_KCAL': 302.0,
#      'PROCNT': 12.85,
#      'FAT': 13.95,
#      'CHOCDF': 31.2,
#      'FIBTG': 2.5},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
#     'image': 'https://www.edamam.com/food-img/ae0/ae0235aa9306072d4ed42bbb1db2c34e.jpg'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pizza',
#      'label': 'Pizza'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_slice',
#      'label': 'Slice'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_aag4g3ebrth98lbqin0bdaor9kyj',
#     'label': 'Thick Crust Cheese Pizza',
#     'nutrients': {'ENERC_KCAL': 271.0,
#      'PROCNT': 10.81,
#      'FAT': 10.54,
#      'CHOCDF': 33.17,
#      'FIBTG': 2.2},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
#     'image': 'https://www.edamam.com/food-img/467/467761701714c582960b0b867fc87042.jpg'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pizza',
#      'label': 'Pizza'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_slice',
#      'label': 'Slice'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_bjs8bt2aa5we6rb5lzzhpan2j82k',
#     'label': 'Thick Crust Pepperoni Pizza',
#     'nutrients': {'ENERC_KCAL': 287.0,
#      'PROCNT': 11.49,
#      'FAT': 12.58,
#      'CHOCDF': 31.84,
#      'FIBTG': 2.2},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
#     'image': 'https://www.edamam.com/food-img/870/87089947933c5623fea56da596c92de3.jpg'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pizza',
#      'label': 'Pizza'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_slice',
#      'label': 'Slice'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_bb5eao4b0bll1gbun64ipbb2dhzp',
#     'label': 'Thin Crust Pepperoni Pizza',
#     'nutrients': {'ENERC_KCAL': 331.0,
#      'PROCNT': 14.01,
#      'FAT': 17.61,
#      'CHOCDF': 29.0,
#      'FIBTG': 2.3},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
#     'image': 'https://www.edamam.com/food-img/85f/85fb002c19c79f9ec454e267138c2d5e.jpg'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pizza',
#      'label': 'Pizza'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_slice',
#      'label': 'Slice'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_b7jjvmkb2reec7b79zmq2adlaboc',
#     'label': 'Thin Crust Sausage Pizza',
#     'nutrients': {'ENERC_KCAL': 321.0,
#      'PROCNT': 13.36,
#      'FAT': 17.71,
#      'CHOCDF': 27.0,
#      'FIBTG': 2.5},
#     'category': 'Generic foods',
#     'categoryLabel': 'food',
#     'image': 'https://www.edamam.com/food-img/e2f/e2fd1708dec69d9e21ceeafcb68208da.jpg'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pizza',
#      'label': 'Pizza'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_slice',
#      'label': 'Slice'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_bhkvugkabk97pyal8z92bb8uiezd',
#     'label': 'Nestle Coffe Mate, Natural Bliss All Natural Coffee Creamer Chocolate',
#     'nutrients': {'ENERC_KCAL': 135.25609080965876,
#      'PROCNT': 0.0,
#      'FAT': 6.762804540482938,
#      'CHOCDF': 20.288413621448814},
#     'brand': 'Bliss',
#     'category': 'Packaged foods',
#     'categoryLabel': 'food',
#     'foodContentsLabel': 'NONFAT MILK; SUGAR; HEAVY CREAM; NATURAL FLAVORS CARAGEENAN (NATURAL THICKENER); CONTAIN: MILK INGREDIENTS.',
#     'image': 'https://www.edamam.com/food-img/38d/38de248c734576daa3b555b324b122f3.JPG'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_package',
#      'label': 'Package'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_tablespoon',
#      'label': 'Tablespoon'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_milliliter',
#      'label': 'Milliliter'}]},
#   {'food': {'foodId': 'food_bdarbn4butz9c2a5muv08bta4pv2',
#     'label': 'Pizza Hut Pan Pizza',
#     'nutrients': {'ENERC_KCAL': 377.74586708553795,
#      'PROCNT': 5.942809066569595,
#      'FAT': 22.773118330907447,
#      'CHOCDF': 37.344488126015655,
#      'FIBTG': 1.5869104476919593},
#     'category': 'Generic meals',
#     'categoryLabel': 'meal',
#     'foodContentsLabel': 'water; dry milk; Salt; Flour; Sugar; yeast; Vegetable oil; Butter; Tomato Sauce; Oregano; Marjoram; Basil; Garlic salt; dough'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit',
#      'label': 'Whole'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_bwwl7rpbo4l0afbjeaj70a48zv3v',
#     'label': 'Pizza',
#     'nutrients': {'ENERC_KCAL': 261.0,
#      'PROCNT': 6.340000152587891,
#      'FAT': 11.270000457763672,
#      'CHOCDF': 32.38999938964844,
#      'FIBTG': 1.399999976158142},
#     'brand': 'Celeste',
#     'category': 'Packaged foods',
#     'categoryLabel': 'food',
#     'foodContentsLabel': 'CRUST (MALTED WHEAT FLOUR (MALTED BARLEY FLOUR); WATER; SHORTENING FLAKE (PALM OIL; SOY LECITHIN; NATURAL BUTTER FLAVOR AND BETA CAROTENE); YEAST; CORN STARCH; SOYBEAN OIL; SUGAR; SALT; DOUGH CONDITIONER (MALT EXTRACT; INACTIVE YEAST; ENZYMES; ENRICHED WHEAT FLOUR [WHEAT FLOUR; NIACIN; REDUCED IRON; THIAMINE MONONITRATE; RIBOFLAVIN; FOLIC ACID]); VITAL WHEAT GLUTEN); SAUCE (WATER; TOMATO PUREE [WATER; TOMATO PASTE]; SEASONING (SALT; SPICES; SUGAR; DEHYDRATED GARLIC); FLAVOR BLEND (MALTODEXTRIN; DEXTROSE; NATURAL SPICE OLEORESINS); SALT; MODIFIED CORN STARCH; SOYBEAN OIL; XANTHAN GUM); TOPPING (IMITATION MOZZARELLA BLEND (WATER; PALM OIL; MODIFIED POTATO STARCH; RENNET CASEIN; MODIFIED CORN STARCH; SODIUM CITRATE; SALT; SODIUM PHOSPHATE; NATURAL FLAVOR; CARRAGEENAN; LACTIC ACID; ARTIFICIAL COLOR); MOZZARELLA (PASTEURIZED CULTURED REDUCED FAT MILK; SALT; ENZYMES); DICED PEPPERONI MADE WITH PORK-CHICKEN ADDED-SMOKE FLAVOR ADDED (PORK; MECHANICALLY SEPARATED CHICKEN; SALT; SPICES; WATER; DEXTROSE; SEASONINGS (NATURAL SPICE EXTRACTIVES; EXTRACTIVES OF PAPRIKA; NATURAL SMOKE FLAVOR; BHA; BHT; CITRIC ACID); LACTIC ACID STARTER CULTURE; SODIUM NITRITE)).',
#     'image': 'https://www.edamam.com/food-img/d42/d42029b44487fe98b8cfc6b54aaebdad.jpg'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pizza',
#      'label': 'Pizza'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_package',
#      'label': 'Package'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_a5chvszbu94ttdbl9buiebg2s989',
#     'label': 'Pizza',
#     'nutrients': {'ENERC_KCAL': 215.03067484662577,
#      'PROCNT': 10.119632416707606,
#      'FAT': 10.739263288813866,
#      'CHOCDF': 19.02147187777092,
#      'FIBTG': 1.1963190476587213},
#     'brand': "Emma's Pub & Pizza",
#     'category': 'Packaged foods',
#     'categoryLabel': 'food',
#     'foodContentsLabel': 'Flour; Bleached Wheat Flour; Malted Barley Flour; Niacin; Iron; Potassium Bromate; Thiamin Mononitrate; Riboflavin; Folic Acid; Cheese; Pasteurized Whole Milk; Cheese Cultures; Salt; Enzymes; Tomato Sauce; Tomatoes; Salt; Citric Acid; Basil; Tomato Puree; Water; Oil; Vegetable Oil; Canola Oil; Olive Oil; Salt; Sugar; Compressed Yeast; Spices; Pepper; Dehydrated Garlic; Onions'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pizza',
#      'label': 'Pizza'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]},
#   {'food': {'foodId': 'food_a64ssp4a1v7pcubi92zkqb6xir0c',
#     'label': 'Pizza',
#     'nutrients': {'ENERC_KCAL': 207.07070707070707,
#      'PROCNT': 9.090909090909092,
#      'FAT': 5.050505050505051,
#      'CHOCDF': 31.81818181818182,
#      'FIBTG': 2.0202020202020203},
#     'brand': "Denny's",
#     'category': 'Fast foods',
#     'categoryLabel': 'meal'},
#    'measures': [{'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving',
#      'label': 'Serving'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram',
#      'label': 'Gram'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce',
#      'label': 'Ounce'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound',
#      'label': 'Pound'},
#     {'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram',
#      'label': 'Kilogram'}]}],
#  '_links': {'next': {'title': 'Next page',
#    'href': 'https://api.edamam.com/api/food-database/parser?session=40&nutrition-type=logging&ingr=coffe+and+pizza&app_id=6b69c52c&app_key=d5a448b534a0c358dfb47fa7a6548724'}}}

# %%
Response_Recipe
